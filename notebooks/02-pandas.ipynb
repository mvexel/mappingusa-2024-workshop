# %% [markdown]
# ## Data processing with Pandas
#
# In the first notebook, we ended up with a small amount of CSV data to work with. Let's see what we can do with it.
#
# We will use `Pandas`, a Python module that specializes in reading, manipulating and analyzing large datasets.
#
# Let's import it into our environment.

# %%
import pandas as pd

# %% [markdown]
# Cool.
#
# For the exercise, I saved the output in `data/shops.csv`. We will load it into a `Dataframe`. A Dataframe holds the data you want to work with, and you can perform all kinds of operations on it.

# %%
df_shops = pd.read_csv('data/shops.csv', delimiter='\t')

df_shops.head()
# Out:
#           shop            name  @version  @timestamp       @lon       @lat
# 0  supermarket           Conad       NaN         NaN  13.636434  42.837053
# 1      butcher        Capretti       NaN         NaN  13.633419  42.820734
# 2  hairdresser  Salone Luciano       NaN         NaN  13.631824  42.820887
# 3       bakery    Forno Fanini       NaN         NaN  13.698427  42.832816
# 4  supermarket             NaN       NaN         NaN  13.681820  42.832053

# %% [markdown]
# Very nice.
#
# In this workshop, I will gloss over some of the details, like the `delimiter` parameter in the command above. We're on a mission to see some results, and there are lots of resources to learn Pandas in depth.
#
# This dataset is small and quite boring, but we are working with real OSM data!
#
# To give you a flavor of what's possible, with a few lines of code, we can create a map of this data in our environment. Don't worry if you don't understand the code. We will start working with more interesting data in the next notebook.

# %%
# folium is a mapping library
import folium

# first, we create the map object and define its center as the mean of the coordinates
# we choose a zoom level of 12
m = folium.Map(location=[df_shops['@lat'].mean(), df_shops['@lon'].mean()], zoom_start=12)

# we add a marker for each shop, with the name as a label
for lat, lon, name in zip(df_shops['@lat'], df_shops['@lon'], df_shops['name']):
    label = name
    label = folium.Popup(label, parse_html=True)
    folium.Marker(
        location=[lat, lon],
        popup=label,
        icon=folium.Icon(color='blue', icon='shopping-cart', prefix='fa')
    ).add_to(m)

# display the map inline
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0cc93dff719f1f92b2630b7ac2ff5ba7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0cc93dff719f1f92b2630b7ac2ff5ba7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0cc93dff719f1f92b2630b7ac2ff5ba7 = L.map(
#                 &quot;map_0cc93dff719f1f92b2630b7ac2ff5ba7&quot;,
#                 {
#                     center: [42.81169336153846, 13.67173845],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8dce734963ffe4649d9be4140c3a3b0b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_8dce734963ffe4649d9be4140c3a3b0b.addTo(map_0cc93dff719f1f92b2630b7ac2ff5ba7);
#
#
#             var marker_e6a2550a78df1a8c4560937a0014e59e = L.marker(
#                 [42.8370527, 13.6364343],
#                 {}
#             ).addTo(map_0cc93dff719f1f92b2630b7ac2ff5ba7);
#
#
#             var icon_b67ef182bfacff4ea7b56a140de86c14 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;shopping-cart&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_e6a2550a78df1a8c4560937a0014e59e.setIcon(icon_b67ef182bfacff4ea7b56a140de86c14);
#
#
#         var popup_1351e6adfce622e30d1b0b3f3d8c3fd2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_549abc8449fb272e42a36a5c3524bb24 = $(`&lt;div id=&quot;html_549abc8449fb272e42a36a5c3524bb24&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Conad&lt;/div&gt;`)[0];
#                 popup_1351e6adfce622e30d1b0b3f3d8c3fd2.setContent(html_549abc8449fb272e42a36a5c3524bb24);
#
#
#
#         marker_e6a2550a78df1a8c4560937a0014e59e.bindPopup(popup_1351e6adfce622e30d1b0b3f3d8c3fd2)
#         ;
#
#
#
#
#             var marker_e0f075930c3050be173aebdd663a28c5 = L.marker(
#                 [42.8207342, 13.6334194],
#                 {}
#             ).addTo(map_0cc93dff719f1f92b2630b7ac2ff5ba7);
#
#
#             var icon_0046f69de92ff1a41f83e7a5619f139a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;shopping-cart&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_e0f075930c3050be173aebdd663a28c5.setIcon(icon_0046f69de92ff1a41f83e7a5619f139a);
#
#
#         var popup_4f0769eae741eab25eda9570fc6cc5fd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_140dd7b2f1cf886aff10ae64ff20bf76 = $(`&lt;div id=&quot;html_140dd7b2f1cf886aff10ae64ff20bf76&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Capretti&lt;/div&gt;`)[0];
#                 popup_4f0769eae741eab25eda9570fc6cc5fd.setContent(html_140dd7b2f1cf886aff10ae64ff20bf76);
#
#
#
#         marker_e0f075930c3050be173aebdd663a28c5.bindPopup(popup_4f0769eae741eab25eda9570fc6cc5fd)
#         ;
#
#
#
#
#             var marker_a24e3e26d2a2ef18b80469699b2768aa = L.marker(
#                 [42.8208865, 13.6318243],
#                 {}
#             ).addTo(map_0cc93dff719f1f92b2630b7ac2ff5ba7);
#
#
#             var icon_aecffd5ff0acbf2ff40d8309d914bed7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;shopping-cart&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_a24e3e26d2a2ef18b80469699b2768aa.setIcon(icon_aecffd5ff0acbf2ff40d8309d914bed7);
#
#
#         var popup_9710cbf3a0920645ca350e874519ebee = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fb2c3b892918fc94bc638af74fc6dbe3 = $(`&lt;div id=&quot;html_fb2c3b892918fc94bc638af74fc6dbe3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Salone Luciano&lt;/div&gt;`)[0];
#                 popup_9710cbf3a0920645ca350e874519ebee.setContent(html_fb2c3b892918fc94bc638af74fc6dbe3);
#
#
#
#         marker_a24e3e26d2a2ef18b80469699b2768aa.bindPopup(popup_9710cbf3a0920645ca350e874519ebee)
#         ;
#
#
#
#
#             var marker_9fa2f3f31290a5f5f7d96c2f4b44867c = L.marker(
#                 [42.8328162, 13.6984273],
#                 {}
#             ).addTo(map_0cc93dff719f1f92b2630b7ac2ff5ba7);
#
#
#             var icon_7a6025e80210f2efddbe859f971c205e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;shopping-cart&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;mark
